# %% [markdown]
# ### Import Statemnts

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Data Exploration

# %%
data = pd.read_csv("D:\Dataset\League of Legend Dataset\champions.csv")
data
# Out:
#     Champion Name     Role  Base Health  Base Mana  Base Armor  \
# 0          Aatrox      Top          580          0          38
# 1            Ahri      Mid          526        418          21
# 2           Akali      Mid          575        200          23
# 3         Alistar  Support          600        350          44
# 4           Amumu   Jungle          615        285          33
# ..            ...      ...          ...        ...         ...
# 144           Zed      Mid          585        200          32
# 145         Ziggs      Mid          536        480          21
# 146        Zilean  Support          504        452          22
# 147           Zoe      Mid          560        425          20
# 148          Zyra  Support          504        418          29
#
#      Base Attack Damage  Gold Efficiency
# 0                    60             1.05
# 1                    53             1.02
# 2                    62             1.03
# 3                    62             1.08
# ...

# %%
# finding what fields are in the dataset
data.columns
# Out:
# Index(['Champion Name', 'Role', 'Base Health', 'Base Mana', 'Base Armor',
#        'Base Attack Damage', 'Gold Efficiency'],
#       dtype='object')

# %%
# finding datatypes of each field
data.dtypes
# Out:
# Champion Name          object
# Role                   object
# Base Health             int64
# Base Mana               int64
# Base Armor              int64
# Base Attack Damage      int64
# Gold Efficiency       float64
# dtype: object

# %% [markdown]
# ### Sumary Statistics

# %%
# finding summary statistics
data.describe()
# Out:
#        Base Health   Base Mana  Base Armor  Base Attack Damage  \
# count   149.000000  149.000000  149.000000          149.000000
# mean    557.241611  313.315436   29.939597           59.476510
# std      36.953340  123.571792    6.801459            5.845516
# min     340.000000    0.000000   17.000000           45.000000
# 25%     532.000000  280.000000   24.000000           55.000000
# 50%     562.000000  325.000000   30.000000           60.000000
# 75%     585.000000  375.000000   35.000000           64.000000
# max     625.000000  800.000000   47.000000           72.000000
#
#        Gold Efficiency
# count       149.000000
# mean          1.042282
# std           0.020438
# min           1.000000
# 25%           1.020000
# 50%           1.040000
# 75%           1.060000
# max           1.100000

# %% [markdown]
# ### Data Types and Missing Values

# %%
# finding if any missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Champion Name       149 non-null    object
#  1   Role                149 non-null    object
#  2   Base Health         149 non-null    int64
#  3   Base Mana           149 non-null    int64
#  4   Base Armor          149 non-null    int64
#  5   Base Attack Damage  149 non-null    int64
#  6   Gold Efficiency     149 non-null    float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 8.3+ KB

# %% [markdown]
# ### Distribution of Numeric Features

# %%
data.hist(bins=10, figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'Base Health'}>,
#         <Axes: title={'center': 'Base Mana'}>],
#        [<Axes: title={'center': 'Base Armor'}>,
#         <Axes: title={'center': 'Base Attack Damage'}>],
#        [<Axes: title={'center': 'Gold Efficiency'}>, <Axes: >]],
#       dtype=object)

# %%
# Creating box plot
plt.figure(figsize=(10, 8))

for i, column in enumerate(data.select_dtypes(include=['int64', 'float64']).columns, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(data[column])
    plt.title(column)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Role Distribution

# %%
# Role distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Role', data=data)
plt.title('Distribution of Roles')
plt.show()

# %% [markdown]
# ### Correlation Matrix

# %%
# Correlation Matrix
plt.figure(figsize=(10, 6))
corelation_matrix = data.drop(columns=['Champion Name', 'Role']).corr()
sns.heatmap(corelation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### Gold Efficiency by Role

# %%
# Gold Efficiency by Role
plt.figure(figsize=(10, 6))
sns.boxplot(x='Role', y='Gold Efficiency', data=data)
plt.title('Gold Efficiency by Role')
plt.show()

# %% [markdown]
# ### Base Mana by Role

# %%
# Boxplot of Base Mana by Role
plt.figure(figsize=(10, 6))
sns.boxplot(x='Role', y='Base Mana', data=data)
plt.title('Base mana by Role')
plt.show()
